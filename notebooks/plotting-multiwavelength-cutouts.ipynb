# %% [markdown]
# # Generating Multiwavelength Cutouts #
# - quick demo of how to generate cutout plots

# %%
import os
import glob

# %%
os.chdir('/home/rfinn/research/Virgo/gui-test2')

# %%
rcutouts = glob.glob('*-R.fits')

# %%
print(rcutouts)
# Out:
# ['VFID3472-WISEAJ131303.16+230503.5-v17p3-R.fits', 'VFID3496-NGC5012A-v17p3-R.fits', 'VFID3489-NGC5012-v17p3-R.fits']

# %%
# %run ~/github/HalphaImaging/python3/plot_cutouts_ha.py --r VFID3496-NGC5012A-v17p3-R.fits
# Out:
# requested legacy imsize =  212.29615327893626
# legacy imsize =  212
# previously downloaded  cutouts/VFID3496-legacy-212.jpg
# previously downloaded  cutouts/VFID3496-legacy-212-g.fits
# legacy imsize =  212
# previously downloaded  cutouts/VFID3496-legacy-212.jpg
# previously downloaded  cutouts/VFID3496-legacy-212-r.fits
# legacy imsize =  212
# previously downloaded  cutouts/VFID3496-legacy-212.jpg
# previously downloaded  cutouts/VFID3496-legacy-212-z.fits
# wise image size =  77.19860119234046
# unwise images already downloaded

# %% [markdown]
# # Plot Halpha Images #

# %%
c.plotcutouts()

# %% [markdown]
# # Plot Star Formation Indicators #

# %%
c.plotsfrcutouts()

# %% [markdown]
# # Plot all wavelengths #

# %%
c.plotallcutouts()

# %% [markdown]
# # Repeat for another galaxy #

# %%
# %run ~/github/HalphaImaging/python3/plot_cutouts_ha.py --r VFID3489-NGC5012-v17p3-R.fits
# Out:
# requested legacy imsize =  212.29615327893626
# legacy imsize =  212
# previously downloaded  cutouts/VFID3489-legacy-212.jpg
# previously downloaded  cutouts/VFID3489-legacy-212-g.fits
# legacy imsize =  212
# previously downloaded  cutouts/VFID3489-legacy-212.jpg
# previously downloaded  cutouts/VFID3489-legacy-212-r.fits
# legacy imsize =  212
# previously downloaded  cutouts/VFID3489-legacy-212.jpg
# previously downloaded  cutouts/VFID3489-legacy-212-z.fits
# wise image size =  77.19860119234046
# unwise images already downloaded

# %%
c.plotallcutouts()

# %% [markdown]
# # Get the Legacy Image from RA, Dec and Size #
#
# *  if you want to just show the legacy image for a particular location

# %%
import os
homedir = os.getenv("HOME")
os.sys.path.append(homedir+'/github/HalphaImaging/python3/')
import plot_cutouts_ha as pc

# %%
# Position of NGC 5012
ra, dec = 197.904330, 22.915491
# download an image of size = 8'
size = 8.*60 # need size in arcsec

# %%
c = pc.cutouts('',ra=ra,dec=dec,size=size,galid='VFID3489-NGC5012') #apparently we need a hyp

# %% [markdown]
# download all the images

# %%
c.runall()
# Out:
# trying to download legacy image
# requested legacy imsize =  480.0
# legacy imsize =  480
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480.jpg
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480-g.fits
# legacy imsize =  480
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480.jpg
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480-r.fits
# legacy imsize =  480
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480.jpg
# previously downloaded  legacy/VFID3489-NGC5012-legacy-480-z.fits
# WARNING: could not get galex pixelscale
# wise image size =  174.54545454545453
# unwise images already downloaded

# %% [markdown]
# ### Plot Legacy jpg ###

# %%
c.plot_legacy_jpg()

# %% [markdown]
# ### Step by step ###

# %%
c.legacy_jpegname
# Out:
# 'legacy/VFID3489-NGC5012-legacy-480.jpg'

# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
jimage = Image.open(c.legacy_jpegname)

# %%
plt.figure()
plt.imshow(jimage,origin='lower')

# %% [markdown]
# ### Plot SFR Indicators ###
#
# * some issues with this - not sure what's doing on here

# %%
c.plotsfrcutouts()
# Out:
# no cs halpha
